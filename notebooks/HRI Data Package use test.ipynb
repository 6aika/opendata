# %%
import pandas, datapackage

# %%
dp = datapackage.push_datapackage("hri/datapackage.json", backend='pandas')

# %%
type(dp)
# Out:
# jsontableschema_pandas.storage.Storage

# %%
dp.tables
# Out:
# ['data___data']

# %%
type(dp.tables)
# Out:
# list

# %%
df = dp['data___data']

# %%
df
# Out:
#        Month of incident  Year of incident                    Address  \
# 0               Toukokuu              2014                       None
# 1               Toukokuu              2014                       None
# 2               Toukokuu              2014                       None
# 3               Toukokuu              2014                       None
# 4               Toukokuu              2014                       None
# 5               Toukokuu              2014                       None
# 6               Toukokuu              2014            Albertinkatu 23
# 7               Toukokuu              2014            Albertinkatu 25
# 8               Toukokuu              2014            Albertinkatu 25
# 9               Toukokuu              2014            Albertinkatu 29
# 10              Toukokuu              2014            Albertinkatu 31
# 11              Toukokuu              2014            Albertinkatu 40
# ...
